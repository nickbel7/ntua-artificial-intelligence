# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Μπέλλος Νικόλας (el18183)
#
# Στοιχεία Μέλους 2: --

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 1
#
#
#
# ---
#
#
#
# Ο στόχος της εργασίας είναι η εφαρμογή αλγορίθμων αναζήτησης και εύρεσης καλύτερου μονοπατιού σε λαβύρινθο διαστάσεων $N\times N$

# %% [markdown]
# # Εκφώνηση
#
# ## Μέρος 1
# Ο στόχος του πρώτου μέρους είναι η κατασκευή **λαβυρίνθων**. [Σε αυτό το άρθρο της Wikipedia](https://en.wikipedia.org/wiki/Maze_generation_algorithm) μπορείτε να βρείτε διάφορους αλγορίθμους για αυτό το σκοπό. Προσέξτε ότι οι αλγόριθμοι του παραπάνω άρθρου κατασκευάζουν ένα μόνο μονοπάτι από κάθε σημείο του λαβυρίνθου προς οποιοδήποτε άλλο (η δομή του λαβυρίνθου έχει μορφή συνεκτικού δέντρου). Καλείστε να τροποποιήσετε τον αλγόριθμο της επιλογής σας (ενδεχομένως και πέραν αυτών που υπάρχουν στο προαναφερθέν άρθρο) ώστε οι λαβύρινθοι που κατασκευάζει να έχουν τουλάχιστον δύο (2) μονοπάτια μεταξύ ενός σημείου αφετηρίας (S) και ενός σημείου τερματισμού (F). Η τροποποίηση του αλγορίθμου μπορεί να γίνει και με πιθανοτικό τρόπο, αλλά σε αυτή την περίπτωση θα πρέπει να βεβαιωθείτε πως οι λαβύρινθοι που θα χρησιμοποιήσετε στα επόμενα ερωτήματα έχουν τουλάχιστον δύο μονοπάτια μεταξύ των S και F. Αναφέρετε ποιον αλγόριθμο επιλέξατε, περιγράψτε τον συνοπτικά καθώς και τον τρόπο που αντιμετωπίσατε το παραπάνω πρόβλημα, και υλοποιήστε τον στο κελί κώδικα του Μέρους 1.
#
# Σε όλα τα ερωτήματα φροντίστε να χρησιμοποιήσετε **δομημένο** κώδικα, με **σχόλια** που επισημαίνουν τη λογική του.
#
#
# ### Παραδείγματα λαβυρίνθων
# ![index1.png](data:image/png;base64,...)
# ![index2.png](data:image/png;base64,...)
# ![index3.png](data:image/png;base64,...)

# %% [markdown]
# ## Μέρος 2
#
# Στο δεύτερο μέρος της εργασίας θα υλοποιήσετε τον αλγόριθμο Α* για την εύρεση συντομότερων μονοπατιών μεταξύ δυο κόμβων για τους λαβυρίνθους που παράγονται από τον κώδικα του πρώτου μέρους. Θα κατασκευάσετε και διάφορες συναρτήσεις κόστους τόσο για την μέτρηση των πραγματικών αποστάσεων όσο και για την εκτίμηση των αποστάσεων από έναν κόμβο στον κόμβο στόχο (heuristic).
#
# Η γενική μορφή της συνάρτησης κόστους στον αλγόριθμο Α* είναι:
# $$f(n)=g(n)+h(n)$$
# Παραπάνω, η συνάρτηση $g(n)$ δίνει την πραγματική απόσταση από το σημείο εκκίνησης μέχρι τον κόμβο $n$, και η συνάρτηση $h(n)$ αποτελεί μια ευριστική της απόστασης από τον κόμβο $n$ μέχρι τον στόχο. Σας ζητείται να πειραματιστείτε με τις εξής επιλογές για τις δύο συναρτήσεις:
# * $g(n)=0$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$. Ποιος αλγόριθμος αναζήτησης προκύπτει; Μπορεί να βρει πάντα το βέλτιστο μονοπάτι;
# * $g(n)=1$ και $h(n)=0$. Ποιος αλγόριθμος αναζήτησης προκύπτει; Μπορεί να βρει πάντα το βέλτιστο μονοπάτι;
# * $g(n)=1$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$. Ποιος αλγόριθμος αναζήτησης προκύπτει; Μπορεί να βρει πάντα το βέλτιστο μονοπάτι;
#
# Μπορείτε να προτείνετε και άλλες ευριστικές συναρτήσεις εκτός από τις αποστάσεις manhattan και euclidean;

# %% [markdown]
# ## Μέρος 3
#
# Στο τρίτο μέρος καλείστε να συγκρίνετε την απόδοση των αλγορίθμων που υλοποιήσατε στο πρώτο μέρος, με βάση την πολυπλοκότητά τους και το κατά πόσο μπορούν να βρούν το βέλτιστο μονοπάτι.
#
# Αρχικά, θα πρέπει να κατασκευάσετε πλήθος λαβυρίνθων με μέγεθος $N\in[10,11, \ldots,50]$ (τουλάχιστον 10 λαβυρίνθους για κάθε Ν).
#
# Έπειτα, για τους τρεις αλγορίθμους που υλοποιήσατε στο δεύτερο μέρος, καθώς και για ό,τι επιπλέον υλοποιήσατε (πχ επιπλέον ευριστικές), ζητείται να συλλέξετε τα εξής χαρακτηριστικά:
#  * το μήκος του ελάχιστου μονοπατιού που εξάγει ο εκάστοτε αλγόριθμος.
#  * το πλήθος των επεκτεταμένων κόμβων (expanded nodes) του κάθε αλγορίθμου, που αποτελεί μέτρο της πολυπλοκότητάς του.
#
# Για να σας είναι εύκολο να εξάγετε συμπεράσματα από τις παραπάνω παραμετροποιήσεις, ζητείται να κατασκευάσετε δύο γραφικές παραστάσεις:
#  * το μήκος του ελάχιστου μονοπατιού συναρτήσει του μεγέθους του χάρτη
#  * το πλήθος των expanded nodes συναρτήσει του μεγέθους του χάρτη
#
# Ένα παράδειγμα φαίνεται παρακάτω:
#
# ![image.png](data:image/png;base64,...)
#
#  Σας ζητείται σχολιάσετε τιςγραφικές παραστάσεις που θα φτιάξετε, και συγκεκριμένα το πώς μεταβάλλεται η συμπεριφορά των αλγορίθμων συναρτήσει του $N$.
#
#  Σημειώνουμε τα παρακάτω:
#
#  * Σε όλα τα παραπάνω πειράματα μπορείτε να λάβετε σαν σημείο εκκίνησης το $(1,1)$ και σαν σημείο τερματισμού $(N-2,N-2)$. Εναλλακτικά, μπορείτε να πειραματιστείτε με τυχαία σημεία εκκινησης και τερματισμού.
#  * Αν και οι χάρτες παράγονται τυχαία, η εκτέλεση αλγορίθμων σε διαφορετικούς χάρτες παράγει μη συγκρίσιμα αποτελέσματα, οπότε οι αλγόριθμοι πρέπει να τρέξουν στους ίδιους χάρτες.
#  * Για λόγους ευκολίας σύγκρισης, προτείνεται να τοποθετήσετε πολλαπλές γραφικές παραστάσεις στο ίδιο σύστημα αξόνων, όπου αυτό είναι εφικτό.
#
# Για το πως κατασκευάζουμε γραφικές παραστάσεις μέσω python, μπορείτε να βρείτε παραδείγματα στον κώδικα που δίνεται, καθώς και (για το ζητούμενο της άσκησης) [εδώ](https://www.kite.com/python/answers/how-to-make-multiple-plots-on-the-same-figure-in-matplotlib-in-python) .
#
# ## **Visualization**
# Παράλληλα με τα παραπάνω σας δίνεται έτοιμη και μια κλάση η όποια κατασκευάζει ένα animation της αναζήτησης το όποιο υλοποιεί κάθε αλγόριθμος. Για την χρήση της κλάσης αυτής πρέπει να κάνετε τα εξής 4 βήματα:
#
# 1.	Δημιουργία ενός instance της κλάσης εκτελώντας την παρακάτω εντολή: `visualization(Start, Goal)`. Η εντολή αυτή δημιουργεί ένα αντικείμενο τύπου visualization.
# 2.	Το βίντεο που παράγεται κάθε φορά ουσιαστικά αποτελείται από stacked frames. Συνεπώς σε κάθε βήμα εκτέλεσης όπου δηλαδή θέλουμε να προσθέσουμε ένα frame στο βίντεο πρέπει να καλέσουμε την μέθοδο της κλάσης: `draw_step(grid, frontier, expanded_nodes)` όπου το πρώτο όρισμα είναι ένας χάρτης (τύπου Maze) το δεύτερο μια λίστα με το μέτωπο της αναζήτηση ενώ το τρίτο μια λίστα με τους κόμβους οι όποιοι έχουν ήδη επεκταθεί από τον αλγόριθμο.
# 3.	(Προαιρετικό) Αν θέλουμε να προσθέσουμε στο animation και το βέλτιστο μονοπάτι που βρήκε ο αλγόριθμός μας μπορούμε να καλέσουμε την μέθοδο add_path(path) η οποία δέχεται σαν όρισμα μια λίστα με όλους τους κόμβους που ανήκουν στο βέλτιστο μονοπάτι (συμπεριλαμβανομένων και των κόμβων αρχής και τέλους).
# 4.	Τέλος καλούμε την συνάρτηση `show_gif()` η όποια εμφανίζει το animation. Επίσης μπορούμε και να αποθηκεύσουμε το gif καλώντας την συνάρτηση `save_gif (filename)` (το αρχείο πρέπει να έχει κατάληξη .gif) καθώς επίσης μπορούμε να εμφανίσουμε μόνο το τελευταίο frame καλώντας την συνάρτηση `show_last_frame()` στο όποιο (αν έχουν γίνει όλα όπως παραπάνω) θα φαίνονται όλοι οι κόμβοι οι οποίοι έχουν επεκταθεί από τον αλγόριθμο, το τελευταίο μέτωπο και (προαιρετικά) και το βέλτιστο μονοπάτι.
#
# Μπορείτε να καταλήξετε στα ίδια συμπεράσματα όσον αφορά την πολυπλοκότητα των αλγορίθμων παρατηρώντας το visualization;

# %% [markdown]
# ## Μέρος 4
#
# Στο τέταρτο και τελευταίο μέρος της εργασίας σας δίνεται η δυνατότητα να κατασκευάσετε λαβυρίνθους με το χέρι.
#
# Καλείστε λοιπόν να **κατασκευάσετε** και να **σχολιάσετε** τους παρακάτω 5 λαβυρίνθους:
#
#
# *   **Λαβύρινθος 1**: Ο Hill-climbing δεν βρίσκει μονοπάτι από την αφετηρία στο στόχο.
# *   **Λαβύρινθος 2**: Ο Α* αργεί όσο το δυνατόν περισσότερο να βρει το βέλτιστο μονοπάτι ανεξαρτήτως της μετρικής απόστασης που χρησιμοποιείται ως ευριστική. Σε τι είδους μονοπάτι η επιλογή διαφορετικής μετρικής απόστασης (Ευκλίδεια/Manhattan) ως ευριστικής οδηγεί τον Α* να βρίσκει το μονοπάτι πιο γρήγορα;
# *   **Λαβύρινθος 3**: Ο αλγόριθμος άπληστης αναζήτησης πρώτα στο καλύτερο (greedy best first) αργεί σημαντικά περισσότερο από τον Α* για να καταλήξει στο στόχο. Σε ποια περίπτωση οι δύο αλγόριθμοι θα συμπεριφέρονταν με τον ίδιο τρόπο;
# *   **Λαβύρινθος 4**: Ο Α* καταφέρνει να βρει το μονοπάτι προς το στόχο σημαντικά πιο γρήγορα από τον Dijkstra. Ο χώρος πρέπει αναγκαστικά να περιέχει εμπόδια. Πώς επηρεάζει το μέγεθος/είδος του εμποδίου τον αριθμό βημάτων που χρειάζεται ο Dijsktra και πώς τον αριθμό βημάτων του Α*;
# *   **Λαβύρινθος 5**: Ο Α* και ο Dijkstra φτάνουν στο στόχο πραγματοποιώντας τον ίδιο ακριβώς αριθμό βημάτων για την προσέγγιση της βέλτιστης διαδρομής. Σημείωση: **αγνοήστε** την τετριμμένη περίπτωση όπου ο Α* συμπεριφέρεται όπως ο Dijkstra (h(n)=0).
#
#
# Ο Α* σε όλες τις περιπτώσεις πραγματοποιεί τη βέλτιστη δυνατή αναζήτηση.
#
#
# Για κάθε λαβύρινθο που σχηματίζετε, δώστε μια σύντομη εξήγηση για την επιλογή σας.
#
# **ΠΡΟΣΟΧΗ:** το output των κελιών που σχηματίζετε διατηρείται για περιορισμένο χρονικό διάστημα στο notebook, γι αυτό καλείστε να αποθηκεύσετε τη φωτογραφία (το πραγματοποιεί η συνάρτηση draw()) και να τη μεταφέρετε στο ανάλογο markdown ώστε να μπορέσουμε να την αξιολογήσουμε.
#
#
# Στη συνέχεια, καλείστε να τρέξετε τους αλγορίθμους pathfinding πάνω στους χάρτες που σχηματίσατε. Για το σκοπό αυτό, μετά την εκτέλεση της draw() καλείτε τη συνάρτηση draw_grid() που μετατρέπει την εικόνα που σχηματίσατε σε χάρτη πάνω στον οποίο μπορούν να τρέξουν οι αλγόριθμοι με χρήση της συνάρτησης pathfinder(). Χρειάζεται να επιλέξετε κατάλληλα τα ορίσματα της pathfinder ώστε να καλέσετε το σωστό αλγόριθμο αναζήτησης σε κάθε ερώτημα. Εκτελέστε τα αντίστοιχα κελιά με τον κώδικα που σας δίνεται και παρουσιάστε την έξοδο αυτών. Φυσικά, εάν ένα ερώτημα περιλαμβάνει την εκτέλεση περισσότερων του ενός αλγορίθμου, αντιγράφετε τα αντίστοιχα κελιά για κάθε αλγόριθμο και τοποθετείτε τα σωστά ορίσματα. Τέλος, η show_gif() σας παρουσιάζει το animation, όπως και στο Μέρος 3.
# **Παρατήρηση:** εφόσον δε σας δίνεται/δεν έχετε υλοποιήσει τον Hill climbing, δε σας ζητείται να τον τρέξετε στο χάρτη που θα σχηματίσετε.

# %% [markdown]
# # Κώδικας visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import PillowWriter
from IPython.display import HTML

class visualization:
    def __init__(self, S, F):
        '''
          Η μέθοδος αυτή αρχικοποιεί ένα αντικείμενο τύπου visualization.
          Είσοδος: 
          -> S: το σημείο εκκίνσης της αναζήτησης
          -> F: το σημείο τερματισμού
        '''
        self.S = S
        self.F = F
        self.images = []
    
    def draw_step(self, grid, frontier, expanded_nodes):
        '''
          Η συνάρτηση αυτή καλείται για να σχεδιαστεί ένα frame στο animation (πρακτικά έπειτα από την επέκταση κάθε κόμβου)
          Είσοδος: 
          -> grid: Ένα χάρτης τύπου grid
          -> frontier: Μια λίστα με τους κόμβους που ανήκουν στο μέτωπο της αναζήτησης
          -> expanded_nodes: Μια λίστα με τους κόμβους που έχουν ήδη επεκταθεί
          Επιστρέφει: None
          Η συνάρτηση αυτή πρέπει να καλεστεί τουλάχιστον μια φορά για να μπορέσει να σχεδιαστει ένα animation (πρεπεί το animation να έχει τουλάχιστον ένα frame).
        '''
        image = np.zeros((grid.N, grid.N, 3), dtype=int)
        image[~grid.grid] = [0, 0, 0]
        image[grid.grid] = [255, 255, 255]
        # Use this to treat 1/True as obstacles
        # image[grid.grid] = [0, 0, 0]
        # image[~grid.grid] = [255, 255, 255]
        
        for node in expanded_nodes:
            image[node] = [0, 0, 128]

        for node in frontier:
            image[node] = [0, 225, 0]

        image[self.S] = [50, 168, 64]
        image[self.F] = [168, 50, 50]
        self.images.append(image)
    
    def add_path(self, path):
        '''
          Η συνάρτηση αυτή προσθέτει στο τελευταίο frame το βέλτιστο μονοπάτι.
          Είσοδος:
          -> path: Μια λίστα η όποια περιέχει το βέλτιστο μονοπάτι (η οποία πρέπει να περιέχει και τον κόμβο αρχή και τον κόμβο στόχο)
          Έξοδος: None
        '''
        for n in path[1:-1]:
            image = np.copy(self.images[-1])
            image[n] = [66, 221, 245]
            self.images.append(image)
        for _ in range (100):
            self.images.append(image)
        
    def create_gif(self, fps = 30, repeat_delay = 2000):
        if len(self.images) == 0:
            raise EmptyStackOfImages("Error! You have to call 'draw_step' at  first.")
        fig = plt.figure()
        plt.axis('off')
        ims = []
        for img in self.images:
            img = plt.imshow(img)
            ims.append([img])
        ani = animation.ArtistAnimation(fig, ims, interval=1000//fps, blit=True, repeat_delay= repeat_delay)
        plt.close(fig)
        return ani
        
    def save_gif(self, filename, fps = 30):
        '''
            Η συνάρτηση αυτή ξαναδημιουργεί και αποθηκεύει το animation σε ένα αρχείο.
            Είσοδος:
            -> Το όνομα του αρχείου με κατάληξη .gif
            Έξοδος: (None)
        '''
        ani = self.create_gif(fps)
        writer = PillowWriter(fps= fps)
        ani.save(filename, writer=writer)

    def show_gif(self, fps= 30, repeat_delay = 2000):
        '''
            Η συνάρτηση αυτή εμφανίζει inline το animation.
            Είσοδος:
            -> fps: τα frames per second
            Έξοδος: Το αντικείμενο που παίζει το animation
            Exceptions: EmptyStackOfImages αν το animation δεν έχει ούτε ένα frame, δηλαδή αν η draw_step δεν έχει καλεστεί ποτέ.
        '''
        ani = self.create_gif(fps, repeat_delay)
        # return HTML(ani.to_html5_video())
        return HTML(ani.to_jshtml())

    def show_last_frame(self):
        '''
            Η μέθοδος αυτή εμφανίζει inline το τελευταίο frame που έχει δημιουργήθει.
            Είσοδος:
            Έξοδος: Το αντικείμενο που εμφανίζει την εικόνα.
            Exceptions: EmptyStackOfImages αν το animation δεν έχει ούτε ένα frame, δηλαδή αν η draw_step δεν έχει καλεστεί ποτέ.
        '''
        if len(self.images) == 0:
            raise EmptyStackOfImages("Error! You have to call 'draw_step' at  first.")
        else:
            plt.imshow(self.images[-1])


class EmptyStackOfImages(Exception):
    pass

# %% [markdown]
# # Λύση

# %% [markdown]
# ## Μέρος 1
#
# Στο παρακάτω κελί κώδικα σας δίνεται ο σκελετός της κλάσης ```Maze```, όπου και θα υλοποιήσετε τον αλγόριθμο κατασκευής λαβυρίνθων. Για να λειτουργεί σωστά η οπτικοποίηση, ο λαβύριθνος αναπαριστάται ως ένας $N\times{N}$ boolean πίνακας στο attribute ```grid``` της κλάσης. Η τιμή ```False``` σε ένα κελί του πίνακα αναπαριστά την ύπαρξη εμποδίου στο σημείο αυτό, ενώ η τιμή ```True``` ελεύθερο κελί.
#
#
# Μπορείτε να τροποποιήσετε τον δοσμένο κώδικα όπως θέλετε.

# %%
# %matplotlib inline
import numpy as np
from queue import LifoQueue
import  random 
import matplotlib.pyplot as plt


class Maze:
    def __init__(self, N, S, F):

      """
      N: integer that indicates the size of the NxN grid of the maze
      S: pair of integers that indicates the coordinates of the starting point (S)
      F: pair of integers that indicates the coordinates of the finish point (F)
      You can add any other parameters you want to customize maze creation (e.g. variables that
      control the creation of additional paths)
      """

      assert N > 2

      ## Make sure start and end are within the grid

      assert S[0] < N-1
      assert S[1] < N-1
      assert F[0] < N-1
      assert F[1] < N-1

      assert S[0] > 0
      assert S[1] > 0
      assert F[0] > 0
      assert F[1] > 0

      # Add here any additional constraints your implementation may have

      self.N = N
      self.S = S
      self.F = F

      # Grid initialized with obstacles (array of 0/False)
      # 1/True indicates available cells
      self.grid = np.zeros((N, N), dtype=bool)
      #-----------------------------------------------------------
      ## YOUR CODE HERE     
      path = []
      
      #RANDOMIZED DFS (Iterative)
      ##1. CHOOSE THE S CELL, MARK IT AS VISITED AND ADD IT TO THE STACK
      stack = LifoQueue()
      stack.put(S)
      self.grid[S] = 1

      ##2. WHILE THE STACK IS NOT EMPTY
      while not stack.empty():
        ##3. POP A CELL FROM THE STACK AND CHECK IF IT HAS UNVISITED NEIGHBOURS
        cell = stack.get()
        walls = []
        if (cell[0]-2 > 0 and self.grid[cell[0]-2,cell[1]] == 0):
          walls.append((cell[0]-1,cell[1]))
        if (cell[0]+2 < N-1 and self.grid[cell[0]+2,cell[1]] == 0):
          walls.append((cell[0]+1,cell[1]))
        if (cell[1]-2 > 0 and self.grid[cell[0],cell[1]-2] == 0):
          walls.append((cell[0],cell[1]-1))
        if (cell[1]+2 < N-1 and self.grid[cell[0],cell[1]+2] == 0):
          walls.append((cell[0],cell[1]+1))
        ##4. IF IT HAS PUSH THE CELL BACK TO THE STACK, CHOOSE ONE WALL, 
        ## BREAK IT, ADD THE NEIGHBOUR TO THE STACK AND MARK IT AS VISITED
        if (walls):
          wall = random.choice(walls) #wall = wall to break
          stack.put(cell) #PUSH THE CURRENT CELL TO THE STACK
          #PUSH THE NEW CELL TO THE STACK
          dx = wall[0] - cell[0]
          dy = wall[1] - cell[1]
          nc = (wall[0]+dx,wall[1]+dy) #nc = new cell
          stack.put(nc)
          self.grid[wall] = 1 #BREAK WALL
          self.grid[nc] = 1 #MARK NEW CELL AS VISITED
          ##CHECK IF NEW CELL IS THE F CELL (IF YES STORE THE PATH)
          if (nc == F):
            tmpStack = LifoQueue()
            ##COPY THE STACK ITEMS TO A LIST (THE LIST IS THE UNIQUE PATH BETWEEN S AND F)
            while not stack.empty():  
              path.append(stack.get())
              tmpStack.put(path[-1])
            while not tmpStack.empty():
              stack.put(tmpStack.get())
      ##5. CREATE MULTIPLE PATHS BETWEEN S AND F
      ##SELECT N RANDOM CELLS, N>=1 FROM THE PATH (S->F) AND BREAK A WALL FOR EACH
      if path:
        npaths = random.randint(1, min(len(path),15))
        for x in range(npaths):
          rc = random.choice(path[1:-1]) #select random cell except S and F, rc = random cell
          rwalls = [] #add to a list all remaining walls
          if (rc[0]-1 > 0 and self.grid[rc[0]-1,rc[1]] == 0):
            rwalls.append((rc[0]-1,rc[1]))
          if (rc[0]+1 < N-1 and self.grid[rc[0]+1,rc[1]] == 0):
            rwalls.append((rc[0]+1,rc[1]))
          if (rc[1]-1 > 0 and self.grid[rc[0],rc[1]-1] == 0):
            rwalls.append((rc[0],rc[1]-1))
          if (rc[1]+1 < N-1 and self.grid[rc[0],rc[1]+1] == 0):
            rwalls.append((rc[0],rc[1]+1))
          
          if rwalls:
            self.grid[random.choice(rwalls)] = 1 #select a random wall from the list and break it
      
      self.grid[F] = 1 #set finish cell to walkable cell
      '''
      # PRIM'S RANDOMIZED ALGORITHM
      ##INITIALIZE WALL LIST
      wallsList = []
      ##SET STARTING AND ENDING POINTS AS PART OF THE MAZE AND ADD THEIR WALLS TO THE WALL LIST
      self.grid[S[0],S[1]] = 1
      if (S[0]-2 > 0):
        wallsList.append((S[0]-1,S[1]))
      if (S[0]+2 < N-1):
        wallsList.append((S[0]+1,S[1]))
      if (S[1]-2 > 0):
        wallsList.append((S[0],S[1]-1))
      if (S[1]+2 < N-1):
        wallsList.append((S[0],S[1]+1))

      ##WE APPEND A WALL IF THE CELL TWO BLOCKS AWAY IS NOT PART OF THE MAZE AND IT IS IN BOUNDS

      ##LOOP THROUGHT WHILE THERE ARE WALLS IN THE LIST
      while wallsList:
        nw = random.choice(wallsList) #nw = next wall
        #EVERY WALL IN THE LIST IS CONNECTED TO AT LEAST ONE CELL OF THE MAZE
        #SO WE HAVE TO CHECK IF IT IS CONNECTED TO ONE OR MORE CELLS
        up = self.grid[nw[0]-1,nw[1]]          #up neighbour
        down = self.grid[nw[0]+1,nw[1]]        #down neighbour
        left = self.grid[nw[0],nw[1]-1]        #left neighbour
        right = self.grid[nw[0],nw[1]+1]       #right neighbour

        #REMOVE ADDED WALL FROM LIST
        wallsList.remove(nw)
        
        ##IF IT IS CONNECTED TO ONLY ONE CELL THEN WE BREAK THE WALL AND MAKE A CONNECTION
        if (sum([up, down, left, right]) == 1):
          self.grid[nw] = 1 #BREAK WALL
          ###ADD NEW CELL TO THE MAZE
          if (up):
            nc = (nw[0]+1,nw[1]) #nc = new cell
            self.grid[nc] = 1
          if (down):
            nc = (nw[0]-1,nw[1])
            self.grid[nc] = 1
          if (left):
            nc = (nw[0],nw[1]+1)
            self.grid[nc] = 1
          if (right):
            nc = (nw[0],nw[1]-1)
            self.grid[nc] = 1

          ##ADD NEW WALLS TO THE LIST (WE USE 1 AS VISITED AND 0 AS NOT VISITED)
          ##FOR A WALL TO BE ADDED THERE HAS TO BE AN UNVISITED NEIGHBOUR (2 BLOCKS AWAY)
          if (nc[0]-2 > 0 and self.grid[nc[0]-2,nc[1]] == 0):
            wallsList.append((nc[0]-1,nc[1]))
          if (nc[0]+2 < N-1 and self.grid[nc[0]+2,nc[1]] == 0):
            wallsList.append((nc[0]+1,nc[1]))
          if (nc[1]-2 > 0 and self.grid[nc[0],nc[1]-2] == 0):
            wallsList.append((nc[0],nc[1]-1))
          if (nc[1]+2 < N-1 and self.grid[nc[0],nc[1]+2] == 0):
            wallsList.append((nc[0],nc[1]+1))
      
      ##WE ENSURE THAT THERE ARE AT LEAST TWO PATHS FROM S TO F
      ###WE ADD ALL REMAINING WALLS (INSIDE BOUNDS) THAT SURROUND FINISH POINT (F) AND BREAK ONE RANDOMLY
      finishWalls = []
      if (F[0]-1 > 0 and self.grid[F[0]-1,F[1]] == 0):    #up wall
        finishWalls.append((F[0]-1,F[1]))
      if (F[0]+1 < N-1 and self.grid[F[0]+1,F[1]] == 0):  #down wall
        finishWalls.append((F[0]+1,F[1]))
      if (F[1]-1 > 0 and self.grid[F[0],F[1]-1] == 0):    #left wall
        finishWalls.append((F[0],F[1]-1))
      if (F[1]+1 < N-1 and self.grid[F[0],F[1]+1] == 0):  #right wall
        finishWalls.append((F[0],F[1]+1))
      
      self.grid[random.choice(finishWalls)] = 1
      
      '''
      #-------------------------------------------------------------------------
      
    def get_grid(self):
        return self.grid

    def draw_map(self, path=None):
        """ Draws the maze as an image. Considers grid values of 0/False to represent obstacles and
        values of 1/True to represent empty cells, but this can be customized. Obstacles are painted
        black and empty cells are painted white. Starting point is painted green and finish point red.
        Optionally accepts as a parameter a path within the maze which is painted blue. 
        """
        image = np.zeros((self.N, self.N, 3), dtype=int)
        image[~self.grid] = [0, 0, 0]
        image[self.grid] = [255, 255, 255]

        # Uncomment the next 2 lines of code to treat 1/True as obstacles (and 0/False as free maze cells)
        # image[self.grid] = [0, 0, 0]
        # image[~self.grid] = [255, 255, 255]

        image[self.S] = [50, 168, 64]
        image[self.F] = [168, 50, 50]
        if path:
            for n in path[1:-1]:
                image[n] = [66, 221, 245]

        plt.imshow(image)
        plt.xticks([])
        plt.yticks([])
        plt.show()

# %% [markdown]
# Τρέξτε το παρακάτω κελί κώδικα πριν παραδώσετε την άσκηση για να φαίνονται παραδείγματα λαβυρίνθων. Μπορείτε να το τροποποιήσετε.

# %%
for N, S, F in ((11, (1, 3), (7, 9)), (25, (3, 7), (23, 19)), (51, (9, 3), (41, 41))):
    map = Maze(N, S, F)
    map.draw_map()

# %% [markdown]
# ### Σχολιασμός
#
# Για τη κατασκευή του λαβυρίνθου χρησιμοποίησα τον Randomized DFS αλγόριθμο (Υλοποίησα και τον Randomized Prim αλγόριθμο με τουλάχιστον 2 μονοπάτια τον οποίο έχω αφήσει σε comments, αλλά επέλεξα τον DFS γιατί δίνει τη δυνατότητα να βρείς εύκολα το μονοπάτι που ενώνει τους S και F, και επομένως, να φτιάξεις πιο εύκολα πολλαπλά μονοπάτια). Ο αλγόριθμος αυτός ξεκινάει από το S κελί, το δηλώνει ως visited και το προσθέτει σε μία lifo στοίβα. Εως ότου να αδειάσει η στοίβα κάνουμε pop το τελευταίο κελί και ελέγχουμε αν έχει unvisited γείτονες. Αν έχει, αρχικά τον ξαναπροσθέτουμε στη στοίβα, διαλέγουμε έναν από αυτούς τυχαία, σπάμε τον τοίχο που τους ενώνει, σημειώνουμε το γείτονα ως visited (δηλαδή 1 στο grid) και τον προσθέτουμε στη στοίβα. Για το πρόβλημα με τα πολλαπλά μονοπάτια, για δημιουργήσουμε περισσότερα από 1 από τον S στον F, αρκεί να βρούμε το μονοπάτι που τους ενώνει το οποίο το κάνουμε εύκολα με τον DFS αντιγράφοντας τα περιεχόμενα της στοίβας μόλις συναντήσουμε το κελί F. Από τη λίστα αυτή που δημιουργείται, διαλέγουμε τυχαία όποια και όσα από αυτά τα κελιά θέλουμε (έχω βάλει να διαλέγει από 1 έως 15) και έπειτα σπάμε ένα γειτονικό τοίχο (που να μην ανήκει στο περίγραμμα του maze). Τέλος, θα πρέπει να σημειωθεί ότι για άρτια Ν ο λαβύρινθος θα έχει διαστάσεις ίδιες με αυτές του N-1 (NxN = N-1xN-1, N%2 = 0), λόγω του άλματος 2 κελιών για κάθε σπάσιμο τοίχου όταν δημιουργούμε το λαβύρινθο με το DFS.

# %% [markdown]
# ## Μέρος 2
#
# Παρακάτω σας δίνετε ο σκελετός της κλάσης Pathfinder η οποία αρχικοποιείται με ένα αντικείμενο ```Maze``` (από το πρώτο μέρος), τη συνάρτηση πραγματικού κόστους ```c``` και την ευριστική ```h```. Σε αυτήν θα υλοποιήσετε τον αλγόριθμο αναζήτησης Α*.

# %%
class Pathfinder:
    def __init__(self, maze, c, h):
        """
        maze : Αντικείμενο τύπου Maze (από Μέρος 1)
        c : Συνάρτηση που υπολογίζει την πραγματική απόσταση μεταξύ δύο σημείων
        h : Συνάρτηση που υπολογίζει την ευριστική μεταξύ δύο σημείων
        """
        self.maze = maze
        self.vis = visualization(maze.S, maze.F)
        self.path = []
        self.cost = c
        self.heuristic = h

        self.closed = []
        
        ### Fill the path list with the coordinates of each point in the path from maze.S to maze.F
        ### Your code here
        #----------------------------------------------------
        # A star Algorithm

        ##1. INITIALIZE OPEN AND CLOSED SETS
        openList = []       #for visualization in optimum time
        open = []           #OPEN SET NODE STRUCTURE : ((x,y), f, parent) 
        closed = []         #CLOSED SET NODE STRUCTURE : (x,y)
        self.closed = closed

        ##2. PLACE STARTING NODE ON THE OPEN SET AND CALCULATE ITS F(n)
        node_s = (maze.S, None, None, 0)
        f = c(node_s) + h(maze.S, maze.F)
        open.append((maze.S, f, None, 0))  #NODE STRUCTURE : ((x,y), f, parent, actual distance)
        openList.append(maze.S)         #for visualization

        ##3. WHILE OPEN IS NOT EMPTY :
        while open:

          ## ADD FRAME TO VISUALIZATION
          self.vis.draw_step(self.maze, openList, closed)

          ##4. TAKE THE NODE WITH SMALLEST F(n)
          curr = min(open, key=lambda t:t[1])

          ##5. IF IT IS THE TARGET NODE RETURN TRUE
          if (curr[0] == maze.F):

            #BACKTRACK TO FIND PATH
            while curr is not None:
              self.path.append(curr[0])
              curr = curr[2]
            self.path = self.path[::-1] #reverse list
            return

          ##5. ELSE REMOVE NODE FROM OPEN SET AND FIND ALL ITS CHILDREN WHICH ARE NOT IN THE CLOSED SET
          open.remove(curr)
          openList.remove(curr[0])      #for visualization
          cell = curr[0]

          ###FIND THE CHILDREN
          children = []

          ## UP CHILD
          if (cell[0]-1 > 0 and maze.grid[cell[0]-1, cell[1]] == 1):
            child = (cell[0]-1, cell[1])
            if (child not in closed):
              # children.append((child, c(maze.S, child)+h(child, maze.F), curr))
              children.append((child, c(curr)+h(child, maze.F), curr, curr[3]+1))
          ### DOWN CHILD
          if (cell[0]+1 < maze.N-1 and maze.grid[cell[0]+1, cell[1]] == 1):
            child = (cell[0]+1, cell[1])
            if (child not in closed):
              # children.append((child, c(maze.S, child)+h(child, maze.F), curr))
              children.append((child, c(curr)+h(child, maze.F), curr, curr[3]+1))
          ### LEFT CHILD
          if (cell[1]-1 > 0 and maze.grid[cell[0], cell[1]-1] == 1):
            child = (cell[0], cell[1]-1)
            if (child not in closed):
              # children.append((child, c(maze.S, child)+h(child, maze.F), curr))
              children.append((child, c(curr)+h(child, maze.F), curr, curr[3]+1))
          ### RIGHT CHILD
          if (cell[1]+1 < maze.N-1 and maze.grid[cell[0], cell[1]+1] == 1):
            child = (cell[0], cell[1]+1)
            if (child not in closed):
              # children.append((child, c(maze.S, child)+h(child, maze.F), curr))
              children.append((child, c(curr)+h(child, maze.F), curr, curr[3]+1))
          
          ##6. CHECK IF EACH CHILD IS ALREADY IN THE OPEN SET (AND REPLACE WHERE NECCESSAIRY)
          for x in children:
            flag = False  #FLAGS THAT CHECKS IF CELL WITH SMALLER F(n) ALREADY EXISTS
            for node in open:
              if (node[0] == x[0] and node[1] > x[1]): #IF CELL WITH BIGGER F(n) EXISTS REMOVE IT
                open.remove(node)
                openList.remove(node[0])      #for visualization
              if (node[0] == x[0] and node[1] <= x[1]): #IF CELL WITH SMALLER OR EQUAL F(n) EXISTS DONT ADD NEW ONE
                flag = True
            if not flag:
              open.append(x)
              openList.append(x[0])           #for visualization

          ##7. PLACE THE CURRENT CELL IN THE CLOSED SET
          closed.append(cell)

        ## ADD FINAL PATH TO VISUALIZATION
        self.vis.add_path(self.path)
        #----------------------------------------------------

    def get_path(self):
        return self.path

    def get_closed_set(self):
        return self.closed

# %% [markdown]
# Για να δείτε το μονοπάτι που κατασκευάσατε, μπορείτε να καλείτε τη μέθοδο ```draw_map``` του αντικειμένου ```maze``` οπως φαίνεται στο παρακάτω κελί.

# %%
import math

## A heuristic (manhattan)
def manhattan(a, b):
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

## B heusistic (euclidian)
def euclidean(a, b):
    return math.sqrt(abs(a[0] - b[0])**2 + abs(a[1] - b[1])**2)

def find_c(a):
    return a[3] + 1

## Create a 41x41 maze
N = 41
S = (5, 9)
F = (37, 37)
maze = Maze(N, S, F)

## Find and visualize the path

## 1a. g(n) = 0, h(n) = manhattan(n)
pf = Pathfinder(maze=maze, c = lambda x: 0, h = manhattan)
maze.draw_map(pf.get_path())
print("1a. g(n) = 0, h(n) = manhattan(n)")
print("Path Length :" + str(len(pf.get_path())))

## 1b. g(n) = 0, h(n) = euclidean(n)
pf = Pathfinder(maze=maze, c = lambda x: 0, h = euclidean)
maze.draw_map(pf.get_path())
print("1b. g(n) = 0, h(n) = euclidean(n)")
print("Path Length :" + str(len(pf.get_path())))

## 2. g(n) = 1, h(n) =  0
pf = Pathfinder(maze=maze, c = lambda x: 1, h = lambda x,y: 0)
maze.draw_map(pf.get_path())
print("2. g(n) = 1, h(n) =  0")
print("Path Length :" + str(len(pf.get_path())))

## 3a. g(n) = 1, h(n) = manhattan(n)
pf = Pathfinder(maze=maze, c = lambda x: 1, h = manhattan)
maze.draw_map(pf.get_path())
print("3a. g(n) = 1, h(n) = manhattan(n)")
print("Path Length :" + str(len(pf.get_path())))

## 3b. g(n) = 1, h(n) = euclidean(n)
pf = Pathfinder(maze=maze, c = lambda x: 1, h = euclidean)
maze.draw_map(pf.get_path())
print("3b. g(n) = 1, h(n) = euclidean(n)")
print("Path Length :" + str(len(pf.get_path())))

## 4. g(n) = S to cell, h(n) = manhattan(n) -> Actual A*
pf = Pathfinder(maze=maze, c = find_c, h = manhattan)
maze.draw_map(pf.get_path())
print("4. g(n) = S to cell, h(n) = manhattan(n)")
print("Path Length :" + str(len(pf.get_path())))
# Out:
# 1a. g(n) = 0, h(n) = manhattan(n)
# Path Length :225
# 1b. g(n) = 0, h(n) = euclidean(n)
# Path Length :345
# 2. g(n) = 1, h(n) =  0
# Path Length :109
# 3a. g(n) = 1, h(n) = manhattan(n)
# Path Length :225
# 3b. g(n) = 1, h(n) = euclidean(n)
# Path Length :345
# 4. g(n) = S to cell, h(n) = manhattan(n)
# Path Length :109

# %% [markdown]
# ## Άλλες Ευριστικές Συναρτήσεις
# Μία εναλλακτική ευριστική πέραν των {manhattan, euclidean} θα μπορούσε να είναι η "Cosine distance" στην οποία ορίζοντας κάποιο σημείο (0,0) στο vector space υπολογίζουμε τα συνημίτονα για τα δύο σημεία {a, b} και υπολογίζουμε τη διαφορά τους. Όσο μικρότερη η διαφορά τους, τόσο πιο κοντά είναι στο χάρτη.

# %% [markdown]
# Για να χρονομετρήσετε το τρέξιμο ενός κελιού μπορείτε να χρησιμοποιήσετε το μαγικό ```%%time```

# %%
# %%time
pf = Pathfinder(maze, c= find_c, h=manhattan)
maze.draw_map(pf.get_path())
# Out:
# CPU times: user 189 ms, sys: 1.83 ms, total: 191 ms
# Wall time: 193 ms

# %% [markdown]
# ## Μέρος 3
#
# Στο παρακάτω κελί σας δίνεται ένα παράδειγμα για την κατασκευή γραφικών παραστάσεων. Θα πρέπει να κατασκευάσετε τις δύο γραφικές παραστάσεις σύμφωνα με τα ζητούμενα της άσκησης.

# %%
## YOUR CODE HERE

## EXAMPLE CODE 
'''
path_lengths_a = [1,2,3,4,5,6,7,8,9]
path_lengths_b = [1,1,2,3,5,8,13,21,34]
map_sizes = [10,20,30,40,50,60,70,80,90]

plt.plot(map_sizes, path_lengths_a)
plt.plot(map_sizes, path_lengths_b )
plt.legend(['algorithm A', 'algorithm B'])
plt.title('Path length vs map size')
plt.show()
'''

#------------------------------------------------------
#INITIALIZE X AXIS, N belongs [10, 50]
map_sizes = [x for x in range(10, 51)]

#INITIALIZE LIST FOR EACH ALGORITHM
path_lengths_1a = []      #Algorithm 1a
expanded_sizes_1a = []
path_lengths_1b = []      #Algorithm 1b
expanded_sizes_1b = []
path_lengths_2 = []       #Algorithm 2
expanded_sizes_2 = []
path_lengths_3a = []      #Algorithm 3a
expanded_sizes_3a = []
path_lengths_3b = []      #Algorithm 3b
expanded_sizes_3b = []
path_lengths_4 = []       #Algorithm 4
expanded_sizes_4 = []

#GENERATE 10 MAPS FOR EACH N
for n in map_sizes:
  avglen = [0, 0, 0, 0, 0, 0]
  avgexp = [0, 0, 0, 0, 0, 0]
  for i in range(10):
    if n % 2 : #check if N (maze size) is odd
      maze = Maze(n, (1,1), (n-2,n-2))
    else :
      maze = Maze(n, (1,1), (n-3,n-3))

    #RUN ALL THE DIFFERENT PATHFINDERS  
    pf = Pathfinder(maze=maze, c = lambda x: 0, h = manhattan)     ## 1a. g(n) = 0, h(n) = manhattan(n)
    avglen[0] += (len(pf.get_path()))
    avgexp[0] += (len(pf.get_closed_set()))

    pf = Pathfinder(maze=maze, c = lambda x: 0, h = euclidean)     ## 1b. g(n) = 0, h(n) = euclidean(n)
    avglen[1] += (len(pf.get_path()))
    avgexp[1] += (len(pf.get_closed_set()))

    pf = Pathfinder(maze=maze, c = lambda x: 1, h = lambda x,y: 0) ## 2. g(n) = 1, h(n) = 0
    avglen[2] += (len(pf.get_path()))
    avgexp[2] += (len(pf.get_closed_set()))

    pf = Pathfinder(maze=maze, c = lambda x: 1, h = manhattan)     ## 3a. g(n) = 1, h(n) = manhattan(n)
    avglen[3] += (len(pf.get_path()))
    avgexp[3] += (len(pf.get_closed_set()))

    pf = Pathfinder(maze=maze, c = lambda x: 1, h = euclidean)     ## 3b. g(n) = 1, h(n) = euclidean(n)
    avglen[4] += (len(pf.get_path()))
    avgexp[4] += (len(pf.get_closed_set()))

    pf = Pathfinder(maze=maze, c=find_c, h=manhattan)              ## 4. g(n) = S to cell, h(n) = manhattan(n) -> Actual A*
    avglen[5] += (len(pf.get_path()))
    avgexp[5] += (len(pf.get_closed_set()))

  #ADD THE AVERAGE VALUE (OUT OF 10) FOR THE SAME N
  path_lengths_1a.append(avglen[0] / 10)
  expanded_sizes_1a.append(avgexp[0] / 10)
  path_lengths_1b.append(avglen[1] / 10)
  expanded_sizes_1b.append(avgexp[1] / 10)
  path_lengths_2.append(avglen[2] / 10)
  expanded_sizes_2.append(avgexp[2] / 10)
  path_lengths_3a.append(avglen[3] / 10)
  expanded_sizes_3a.append(avgexp[3] / 10)
  path_lengths_3b.append(avglen[4] / 10)
  expanded_sizes_3b.append(avgexp[4] / 10)
  path_lengths_4.append(avglen[5] / 10)
  expanded_sizes_4.append(avgexp[5] / 10)
  

#1. LENGTH OF OPTIMUM PATH
plt.plot(map_sizes, path_lengths_1a, label="1a.g(n)=0, h(n)=manhattan(n)")
plt.plot(map_sizes, path_lengths_1b, label="1b.g(n)=0, h(n)=euclidean(n)")
plt.plot(map_sizes, path_lengths_2, label="2.g(n)=1, h(n)=0")
plt.plot(map_sizes, path_lengths_3a, label="3a.g(n)=1, h(n)=manhattan(n)")
plt.plot(map_sizes, path_lengths_3b, label="3b.g(n)=1, h(n)=euclidean(n)")
plt.plot(map_sizes, path_lengths_4, label="4.g(n)=sum(S,n), h(n)=manhattan(n)")
plt.title('Path length vs Map size')
plt.legend()
plt.show()

#2. NUMBER OF EXPANDED NODES
plt.plot(map_sizes, expanded_sizes_1a, label="1a.g(n)=0, h(n)=manhattan(n)")
plt.plot(map_sizes, expanded_sizes_1b, label="1b.g(n)=0, h(n)=euclidean(n)")
plt.plot(map_sizes, expanded_sizes_2, label="2.g(n)=1, h(n)=0")
plt.plot(map_sizes, expanded_sizes_3a, label="3a.g(n)=1, h(n)=manhattan(n)")
plt.plot(map_sizes, expanded_sizes_3b, label="3b.g(n)=1, h(n)=euclidean(n)")
plt.plot(map_sizes, expanded_sizes_4, label="4.g(n)=sum(S,n), h(n)=manhattan(n)")
plt.title('Expanded nodes vs Map size')
plt.legend()
plt.show()  

#------------------------------------------------------

# %% [markdown]
# ###Σχολιασμός
# **Disclaimer :** *Για να τρέχει πιο γρήγορα ο παρακάτω κώδικας για τα γραφήματα, πρέπει να πατε στο κώδικα του 2ου ερωτήματος, (με Ctrl + F) να βρείτε το draw_step και να το κάνετε comment out*
#
# ####Γράφημα 1ο (Ελάχιστα μονοπάτια)
# Όσον αφορά το γράφημα με τα μήκη ελάχιστων μονοπατιών : Αρχικά, παρατηρούμε ότι εμφανίζονται μόνο 3 από τις 6 συναρτήσεις στο γράφημα, διότι τα ζευγάρια {1a,3a}, {1b,3b} και {2,4} ταυτίζονται, καθώς βρίσκουν το ίδιο μονοπάτι.  μπορούμε να διαπιστώσουμε ότι ο Α\* με g(n) την πραγματική απόσταση από τον αρχικό κόμβο σε όλες τις περιπτώσεις βρίσκει το μικρότερο μονοπάτι, όπως και ο αλγόριθμος 2 με g(n)=1, h(n)=0. Τώρα για τους {1a,1b,3a,3b}, οι οποίοι είναι πρακτικά αλγόριθμοι best first παρατηρούμε ότι όσο μεγαλώνει το Ν τείνουν να βρίσκουν μονοπάτια που αποκλείνουν όλο και περισσότερο από αυτά του κανονικού Α\*. Μεταξύ τους, έχουν ελάχιστες διαφορές, ανάλογα με τη συνάρτηση ευριστικής h(n) {manhattan, euclidean}. Τα μονοπάτια φαίνεται στη γενική πρερίπτωση να έχουν μήκη περίπου $$Path \: Length \sim \frac{Ν^{2}}{8}$$
#
# ####Γράφημα 2ο (Πλήθος των expanded nodes)
# Τώρα, όσον αφορά το 2ο γράφημα. Οι γραφικές από τα ζευγάρια {1a,3a} και {1b,3b} ταυτίζονται, καθώς η διαφορά στην g(n) στο νούμερο της σταθεράς δεν αλλάζει τον αλγόριθμο και οι 4 αυτοί συμπεριφέρονται σαν τον αλγόριθμο Best-first. Αυτά τα δύο ζευγάρια Αλγορίθμων, φαίνεται να παράγουν τα μικρότερα πλήθη expanded nodes, τα οποία είναι σαν τάξη μεγέθους περίπου $$Closed \: Set _{Algo \: 1a,1b,3a,3b} \sim \frac{Ν^{2}}{6}$$. Αμέσως μετά, ο πραγματικός αλγόριθμος Α\* (με συνάρτηση g(n) οσο η πραγματική απόσταση από τον S) ενώ βρίσκει το βέλτιστο πάντα μονοπάτι δημιουργεί πλήθος expanded nodes της τάξης του $$Closed \: Set _{Algo \: 4} \sim \frac{Ν^{2}}{4}$$ Τέλος, ο  **αλγόριθμος 2** (ο οποίος για κάθε κελί επιστρέφει πάντα την ίδια ευριστική), ενώ βρίσκει θεωρητικά πάντα το βέλτιστο μονοπάτι το πλήθος του closed set που παράγει είναι $$Closed \: Set _{Algo \: 2} \sim \, \frac{N^{2}}{3}$$, γιατί εξερευνεί όλα τα μονοπάτια ταυτόχρονα.

# %% [markdown]
# ## Μέρος 4
#
# Σας δίνεται η συνάρτηση ```draw(filename='filename.png')``` η οποία παράγει ένα interactive grid ώστε να σχηματίσετε το λαβύρινθο. Θεωρήστε ως μαύρο το χρώμα του εμποδίου, πράσινο την αφετηρία και κόκκινο το στόχο, και πατήστε finish για να ολοκληρωθεί η εκτέλεση του τρέχοντος κελιού. Σε περίπτωση που θέλετε να παράξετε νέο λαβύρινθο, απλά ξανατρέξτε το κελί, επιλέξτε τα τετράγωνα και πατήστε finish. Κάθε εκτέλεση αποθηκεύει την εικόνα σε μορφή png σε όνομα που μπορείτε να καθορίσετε μέσω του filename (τοποθετώντας και την κατάληξη .png) κατά την κλήση της συνάρτησης.
#
# Μπορείτε να το δοκιμάσετε τρέχοντας το επόμενο κελί κώδικα.

# %%
from IPython.display import HTML, Image
from google.colab.output import eval_js
from base64 import b64decode
import PIL


canvas_html = """
<canvas width=301 height=301></canvas>
<br>

<button id = "start" style="background-color: #008000">Start</button>
<button id = "end" style="background-color: #800000">End</button>
<button id = "finish">Finish</button>
<script>

var canvas = document.querySelector('canvas')
var ctx = canvas.getContext('2d')

for (var x = 0.5; x < 301; x += 20) {
  ctx.moveTo(x, 0);
  ctx.lineTo(x, 300);
}

for (var y = 0.5; y < 301; y += 20) {
  ctx.moveTo(0, y);
  ctx.lineTo(300, y);
}

ctx.strokeStyle = "#000";
ctx.stroke();

var button = document.getElementById('finish')
var start_button = document.getElementById('start')
var end_button = document.getElementById('end')


start_button.onclick = ()=>{
    ctx.fillStyle="#008000";
  }

end_button.onclick = ()=>{
    ctx.fillStyle="#800000";
  }
   

var mouse = {x: 0, y: 0}
canvas.addEventListener('mousemove', function(e) {
  mouse.x = e.pageX - this.offsetLeft
  mouse.y = e.pageY - this.offsetTop
})

function getMousePos(canvas, evt) {
        var rect = canvas.getBoundingClientRect();
        return {
          x: evt.x - rect.left,
          y: evt.y - rect.top
        };
      }

function getNearestSquare(position) {
    var x = position.x;
    var y = position.y;

    if (x < 0 || y < 0) return null;
    x = (Math.floor(x / 20) * 20) + 0.5
    y = (Math.floor(y / 20) * 20) + 0.5
    return {x: x, y: y};
}

function containsObject(obj, list) {
    var i;
    for (i = 0; i < list.length; i++) {
        if (list[i].x === obj.x && list[i].y == obj.y) {
            return i;
        }
    }
    return -1;
}

borders = []

canvas.onmousedown = ()=>{
    var pos = getNearestSquare(getMousePos(canvas, mouse));
    if (pos != null) {
        index = containsObject(pos, borders)
        if (index != -1){
            borders.splice(index, 1)
            ctx.clearRect(pos.x + 1, pos.y, 19, 19)
        }
        else{
            ctx.fillRect(pos.x+1,pos.y+1,18,18);
            borders.push(pos)
        }
        ctx.fillStyle="#000000";
    }
}
var data = new Promise(resolve=>{
  button.onclick = ()=>{
    resolve(canvas.toDataURL('image/png'))
  }
})
</script>
"""

def draw(filename='drawing.png'):
  display(HTML(canvas_html))
  data = eval_js("data")
  print (data)
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return len(binary)


draw()
# Out:
# <canvas width=301 height=301></canvas>
# <br>
#
# <button id = "start" style="background-color: #008000">Start</button>
# <button id = "end" style="background-color: #800000">End</button>
# <button id = "finish">Finish</button>
# <script>
#
# var canvas = document.querySelector('canvas')
# var ctx = canvas.getContext('2d')
#
# for (var x = 0.5; x < 301; x += 20) {
#   ctx.moveTo(x, 0);
#   ctx.lineTo(x, 300);
# }
#
# for (var y = 0.5; y < 301; y += 20) {
#   ctx.moveTo(0, y);
#   ctx.lineTo(300, y);
# }
#
# ctx.strokeStyle = "#000";
# ctx.stroke();
#
# var button = document.getElementById('finish')
# var start_button = document.getElementById('start')
# var end_button = document.getElementById('end')
#
#
# start_button.onclick = ()=>{
#     ctx.fillStyle="#008000";
#   }
#
# end_button.onclick = ()=>{
#     ctx.fillStyle="#800000";
#   }
#
#
# var mouse = {x: 0, y: 0}
# canvas.addEventListener('mousemove', function(e) {
#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop
# })
#
# function getMousePos(canvas, evt) {
#         var rect = canvas.getBoundingClientRect();
#         return {
#           x: evt.x - rect.left,
#           y: evt.y - rect.top
#         };
#       }
#
# function getNearestSquare(position) {
#     var x = position.x;
#     var y = position.y;
#
#     if (x < 0 || y < 0) return null;
#     x = (Math.floor(x / 20) * 20) + 0.5
#     y = (Math.floor(y / 20) * 20) + 0.5
#     return {x: x, y: y};
# }
#
# function containsObject(obj, list) {
#     var i;
#     for (i = 0; i < list.length; i++) {
#         if (list[i].x === obj.x && list[i].y == obj.y) {
#             return i;
#         }
#     }
#     return -1;
# }
#
# borders = []
#
# canvas.onmousedown = ()=>{
#     var pos = getNearestSquare(getMousePos(canvas, mouse));
#     if (pos != null) {
#         index = containsObject(pos, borders)
#         if (index != -1){
#             borders.splice(index, 1)
#             ctx.clearRect(pos.x + 1, pos.y, 19, 19)
#         }
#         else{
#             ctx.fillRect(pos.x+1,pos.y+1,18,18);
#             borders.push(pos)
#         }
#         ctx.fillStyle="#000000";
#     }
# }
# var data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>
# data:image/png;base64,...
# 4370

# %% [markdown]
# Οι συναρτήσεις στο παρακάτω κελί κώδικα είναι βοηθητικές. Μετατρέπουν την εικόνα που αποθηκεύεται από την ```draw``` του προηγούμενου κελιου ξανά σε αντικείμενο τύπου Maze για να μπορέσετε να τρέξετε τους αλγορίθμους που έχετε υλοποιήσει καθώς και τον κώδικα visualization που σας δίνεται.

# %%
def find_points(image_array, pixels):
    points = []
    for grid_i, i in enumerate(range (10, image_array.shape[0]-10, 20)):
        for grid_j, j in enumerate(range (10, image_array.shape[1]-10, 20)):
            if np.array_equal(image_array[i][j], pixels):
                points.append([grid_i+1, grid_j+1])
    return points

def load_maze(fname='/content/drawing.png'):
    N = 17
    image = PIL.Image.open(fname)
    image_array = np.round(np.array(image)/255)

    start_x, start_y = find_points(image_array, [0,1,0,1])[0]
    end_x, end_y = find_points(image_array, [1, 0, 0, 1])[0]
    walls = find_points(image_array, [0, 0, 0, 1])
    new_grid = Maze(N, (start_x, start_y), (end_x, end_y))

    for i in range(N):
        for j in range(N):
            if [i, j] in walls:
                new_grid.grid[i,j] = 0
            else:
                new_grid.grid[i, j] = 1

    g = new_grid
    g.draw_map()
    return g

# %% [markdown]
# Υπενθυμίζεται ότι το output των κελιών που σχηματίζετε διατηρείται για περιορισμένο χρονικό διάστημα στο notebook, γι αυτό καλείστε να αποθηκεύσετε τη φωτογραφία (το πραγματοποιεί η συνάρτηση draw()) και να τη μεταφέρετε στο ανάλογο markdown.

# %% [markdown]
# ### 4.1.

# %%
draw(filename='4.1.png')
# Out:
# <canvas width=301 height=301></canvas>
# <br>
#
# <button id = "start" style="background-color: #008000">Start</button>
# <button id = "end" style="background-color: #800000">End</button>
# <button id = "finish">Finish</button>
# <script>
#
# var canvas = document.querySelector('canvas')
# var ctx = canvas.getContext('2d')
#
# for (var x = 0.5; x < 301; x += 20) {
#   ctx.moveTo(x, 0);
#   ctx.lineTo(x, 300);
# }
#
# for (var y = 0.5; y < 301; y += 20) {
#   ctx.moveTo(0, y);
#   ctx.lineTo(300, y);
# }
#
# ctx.strokeStyle = "#000";
# ctx.stroke();
#
# var button = document.getElementById('finish')
# var start_button = document.getElementById('start')
# var end_button = document.getElementById('end')
#
#
# start_button.onclick = ()=>{
#     ctx.fillStyle="#008000";
#   }
#
# end_button.onclick = ()=>{
#     ctx.fillStyle="#800000";
#   }
#
#
# var mouse = {x: 0, y: 0}
# canvas.addEventListener('mousemove', function(e) {
#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop
# })
#
# function getMousePos(canvas, evt) {
#         var rect = canvas.getBoundingClientRect();
#         return {
#           x: evt.x - rect.left,
#           y: evt.y - rect.top
#         };
#       }
#
# function getNearestSquare(position) {
#     var x = position.x;
#     var y = position.y;
#
#     if (x < 0 || y < 0) return null;
#     x = (Math.floor(x / 20) * 20) + 0.5
#     y = (Math.floor(y / 20) * 20) + 0.5
#     return {x: x, y: y};
# }
#
# function containsObject(obj, list) {
#     var i;
#     for (i = 0; i < list.length; i++) {
#         if (list[i].x === obj.x && list[i].y == obj.y) {
#             return i;
#         }
#     }
#     return -1;
# }
#
# borders = []
#
# canvas.onmousedown = ()=>{
#     var pos = getNearestSquare(getMousePos(canvas, mouse));
#     if (pos != null) {
#         index = containsObject(pos, borders)
#         if (index != -1){
#             borders.splice(index, 1)
#             ctx.clearRect(pos.x + 1, pos.y, 19, 19)
#         }
#         else{
#             ctx.fillRect(pos.x+1,pos.y+1,18,18);
#             borders.push(pos)
#         }
#         ctx.fillStyle="#000000";
#     }
# }
# var data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>
# data:image/png;base64,...
# 5140

# %%
g = load_maze('/content/4.1.png')

# %% [markdown]
# #### Φωτογραφία για το 4.1 όπως προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
# ![download.png](data:image/png;base64,...)
#
# ![4.1.png](data:image/png;base64,...)
#
# #### Σχολιασμός
# Ο αλγόριθμος Hill Climbing ψάχνει να βρεί μία διαδρομή η οποία να έχει γνησίως φθήνουσες ευριστικές. Αυτό σημαίνει ότι θα βρίσκει μονοπάτι μόνο όταν συνεχώς πλησιάζει στο στόχο και πιο πρακτικά, όταν η διάσχηση του μονοπατιού απαιτεί το πολύ δύο κατευθύνσεις. Για να μην μπορεί λοιπόν να βρεί το μονοπάτι, αρκεί σε κάθε πιθανή διαδρομή να υπάρχει ένα σημείο στο οποίο θα πρέπει να απομακρυνθεί από το στόχο για να φτάσει σε εκείνον. Στο συγκεκριμένο χάρτη αυτό θα συμβεί όταν το μονοπάτι θα αρχίσει να ανηφορίζει.

# %% [markdown]
# ### 4.2.

# %%
draw(filename='4.2.png')
# Out:
# <canvas width=301 height=301></canvas>
# <br>
#
# <button id = "start" style="background-color: #008000">Start</button>
# <button id = "end" style="background-color: #800000">End</button>
# <button id = "finish">Finish</button>
# <script>
#
# var canvas = document.querySelector('canvas')
# var ctx = canvas.getContext('2d')
#
# for (var x = 0.5; x < 301; x += 20) {
#   ctx.moveTo(x, 0);
#   ctx.lineTo(x, 300);
# }
#
# for (var y = 0.5; y < 301; y += 20) {
#   ctx.moveTo(0, y);
#   ctx.lineTo(300, y);
# }
#
# ctx.strokeStyle = "#000";
# ctx.stroke();
#
# var button = document.getElementById('finish')
# var start_button = document.getElementById('start')
# var end_button = document.getElementById('end')
#
#
# start_button.onclick = ()=>{
#     ctx.fillStyle="#008000";
#   }
#
# end_button.onclick = ()=>{
#     ctx.fillStyle="#800000";
#   }
#
#
# var mouse = {x: 0, y: 0}
# canvas.addEventListener('mousemove', function(e) {
#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop
# })
#
# function getMousePos(canvas, evt) {
#         var rect = canvas.getBoundingClientRect();
#         return {
#           x: evt.x - rect.left,
#           y: evt.y - rect.top
#         };
#       }
#
# function getNearestSquare(position) {
#     var x = position.x;
#     var y = position.y;
#
#     if (x < 0 || y < 0) return null;
#     x = (Math.floor(x / 20) * 20) + 0.5
#     y = (Math.floor(y / 20) * 20) + 0.5
#     return {x: x, y: y};
# }
#
# function containsObject(obj, list) {
#     var i;
#     for (i = 0; i < list.length; i++) {
#         if (list[i].x === obj.x && list[i].y == obj.y) {
#             return i;
#         }
#     }
#     return -1;
# }
#
# borders = []
#
# canvas.onmousedown = ()=>{
#     var pos = getNearestSquare(getMousePos(canvas, mouse));
#     if (pos != null) {
#         index = containsObject(pos, borders)
#         if (index != -1){
#             borders.splice(index, 1)
#             ctx.clearRect(pos.x + 1, pos.y, 19, 19)
#         }
#         else{
#             ctx.fillRect(pos.x+1,pos.y+1,18,18);
#             borders.push(pos)
#         }
#         ctx.fillStyle="#000000";
#     }
# }
# var data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>
# data:image/png;base64,...
# 5265

# %% [markdown]
# #### Φωτογραφία από το 4.2 όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
# ![download (4).png](data:image/png;base64,...)
#
#
# ![4.2.png](data:image/png;base64,...)
#
# #### Σχολιασμός
# Ο Α* αργεί όταν θα πρέπει με κάποιο τρόπο να εξερευνήσει πάρα πολλούς κόβμους του λαβυρίνθου. Αυτό γίνεται όταν δεν υπάρχει λύση ή όταν το μονοπάτι καλύπτει όσο το δυνατόν περισσότερα κελιά του grid. Για να εξερευνήσει λοιπόν, πάρα πολλά κελιά, θα πρέπει να ακολουθήσει πολλά μονοπάτια τα οποία τον οδηγούν πολύ κοντά στη λύση αλλά βρίσκουν τοίχο προς το τέλος ή θα μπορούσε ο λαβύρινθος να περιέχει μονοπάτι που καλύπτει όλο το πεδίο, δηλαδή περίπου NxN κελιά (τετραγωνική πολυπλοκότητα). Οπότε, σε αυτή περίπτωση του λαβυρίνθου (όπως φαίνεται και στο σχήμα), θα πρέπει να καλυφθεί όσο το δυνατόν μεγαλύτερη απόσταση μέχρι να φτάσει ο αλγόριθμος στο στόχο.

# %%
g = load_maze('4.2.png')

# %%
# %%time
pf = Pathfinder(g,  c = find_c, h = manhattan)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())
# Out:
# CPU times: user 55.7 ms, sys: 408 µs, total: 56.1 ms
# Wall time: 59.4 ms

# %%
pf.vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd58615e3b63f4e94ba54784e5e45ee3c">
#   <div class="anim-controls">
#     <input id="_anim_sliderd58615e3b63f4e94ba54784e5e45ee3c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd58615e3b63f4e94ba54784e5e45ee3c.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animd58615e3b63f4e94ba54784e5e45ee3c.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectd58615e3b63f4e94ba54784e5e45ee3c" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d58615e3b63f4e94ba54784e5e45ee3c"
#              >
#       <label for="_anim_radio1_d58615e3b63f4e94ba54784e5e45ee3c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d58615e3b63f4e94ba54784e5e45ee3c"
#              checked>
#       <label for="_anim_radio2_d58615e3b63f4e94ba54784e5e45ee3c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d58615e3b63f4e94ba54784e5e45ee3c"
#              >
#       <label for="_anim_radio3_d58615e3b63f4e94ba54784e5e45ee3c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd58615e3b63f4e94ba54784e5e45ee3c";
#     var slider_id = "_anim_sliderd58615e3b63f4e94ba54784e5e45ee3c";
#     var loop_select_id = "_anim_loop_selectd58615e3b63f4e94ba54784e5e45ee3c";
#     var frames = new Array(97);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAEzElEQVR4nO3cwU0DMRBAUYxSEWmAMigRuqACWjIt\
# kFUS+y/vnSPt+JKvucyYc84XAIh5XT0AABwhYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAk\
# YAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKA\
# AZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIG\
# QJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkXVYPwBpjjNUjwDJzztUjcAc2MACSBAyAJAEDIEnAAEgS\
# MACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEhyzJc/e/t8v+n3Px/fN39j5yOrRw4g7/qe//4W\
# zsEGBkCSgAGQJGAAJAkYAEkCBk

# %% [markdown]
# ### 4.3.

# %%
draw(filename='4.3.png')
# Out:
# <canvas width=301 height=301></canvas>
# <br>
#
# <button id = "start" style="background-color: #008000">Start</button>
# <button id = "end" style="background-color: #800000">End</button>
# <button id = "finish">Finish</button>
# <script>
#
# var canvas = document.querySelector('canvas')
# var ctx = canvas.getContext('2d')
#
# for (var x = 0.5; x < 301; x += 20) {
#   ctx.moveTo(x, 0);
#   ctx.lineTo(x, 300);
# }
#
# for (var y = 0.5; y < 301; y += 20) {
#   ctx.moveTo(0, y);
#   ctx.lineTo(300, y);
# }
#
# ctx.strokeStyle = "#000";
# ctx.stroke();
#
# var button = document.getElementById('finish')
# var start_button = document.getElementById('start')
# var end_button = document.getElementById('end')
#
#
# start_button.onclick = ()=>{
#     ctx.fillStyle="#008000";
#   }
#
# end_button.onclick = ()=>{
#     ctx.fillStyle="#800000";
#   }
#
#
# var mouse = {x: 0, y: 0}
# canvas.addEventListener('mousemove', function(e) {
#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop
# })
#
# function getMousePos(canvas, evt) {
#         var rect = canvas.getBoundingClientRect();
#         return {
#           x: evt.x - rect.left,
#           y: evt.y - rect.top
#         };
#       }
#
# function getNearestSquare(position) {
#     var x = position.x;
#     var y = position.y;
#
#     if (x < 0 || y < 0) return null;
#     x = (Math.floor(x / 20) * 20) + 0.5
#     y = (Math.floor(y / 20) * 20) + 0.5
#     return {x: x, y: y};
# }
#
# function containsObject(obj, list) {
#     var i;
#     for (i = 0; i < list.length; i++) {
#         if (list[i].x === obj.x && list[i].y == obj.y) {
#             return i;
#         }
#     }
#     return -1;
# }
#
# borders = []
#
# canvas.onmousedown = ()=>{
#     var pos = getNearestSquare(getMousePos(canvas, mouse));
#     if (pos != null) {
#         index = containsObject(pos, borders)
#         if (index != -1){
#             borders.splice(index, 1)
#             ctx.clearRect(pos.x + 1, pos.y, 19, 19)
#         }
#         else{
#             ctx.fillRect(pos.x+1,pos.y+1,18,18);
#             borders.push(pos)
#         }
#         ctx.fillStyle="#000000";
#     }
# }
# var data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>
# data:image/png;base64,...
# 5942

# %% [markdown]
# #### Φωτογραφία από το 4.3 όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
# ![download (5).png](data:image/png;base64,...)
#
# ![4.3.png](data:image/png;base64,...)
#
# #### Σχολιασμός
# Ο Best First λαμβάνει υπόψην μόνο τις τιμές των ευριστικών, με αποτέλεσμα να μην "ενδιαφέρεται" για το πόση απόσταση έχει διανύσει. Ο Α* μπορεί να εκμεταλευτεί την απόσταση που ξέρει ότι έχει διανύσει σε κάθε σημείο ώστε να μην επεκτείνει μονοπάτια τα οποία πλησιάζουν φαινομενικά στο στόχο, αλλά ταυτόχρονα δημιουργούν πολύ μεγάλες ουρές από το αρχικό σημείο. Οι δύο αλγόριθμοι ταυτίζονται όταν η συνάρτηση g(n) που χρησιμοποιεί ο Α* για την εκτιμήτρια συνάρτηση ισούται με 0.

# %%
g = load_maze('4.3.png')

# %%
pf = Pathfinder(g, c = find_c, h = manhattan)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())

# %%
pf.vis.show_gif()

# %% [markdown]
# ### 4.4.

# %%
draw(filename='4.4.png')
# Out:
# <canvas width=301 height=301></canvas>
# <br>
#
# <button id = "start" style="background-color: #008000">Start</button>
# <button id = "end" style="background-color: #800000">End</button>
# <button id = "finish">Finish</button>
# <script>
#
# var canvas = document.querySelector('canvas')
# var ctx = canvas.getContext('2d')
#
# for (var x = 0.5; x < 301; x += 20) {
#   ctx.moveTo(x, 0);
#   ctx.lineTo(x, 300);
# }
#
# for (var y = 0.5; y < 301; y += 20) {
#   ctx.moveTo(0, y);
#   ctx.lineTo(300, y);
# }
#
# ctx.strokeStyle = "#000";
# ctx.stroke();
#
# var button = document.getElementById('finish')
# var start_button = document.getElementById('start')
# var end_button = document.getElementById('end')
#
#
# start_button.onclick = ()=>{
#     ctx.fillStyle="#008000";
#   }
#
# end_button.onclick = ()=>{
#     ctx.fillStyle="#800000";
#   }
#
#
# var mouse = {x: 0, y: 0}
# canvas.addEventListener('mousemove', function(e) {
#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop
# })
#
# function getMousePos(canvas, evt) {
#         var rect = canvas.getBoundingClientRect();
#         return {
#           x: evt.x - rect.left,
#           y: evt.y - rect.top
#         };
#       }
#
# function getNearestSquare(position) {
#     var x = position.x;
#     var y = position.y;
#
#     if (x < 0 || y < 0) return null;
#     x = (Math.floor(x / 20) * 20) + 0.5
#     y = (Math.floor(y / 20) * 20) + 0.5
#     return {x: x, y: y};
# }
#
# function containsObject(obj, list) {
#     var i;
#     for (i = 0; i < list.length; i++) {
#         if (list[i].x === obj.x && list[i].y == obj.y) {
#             return i;
#         }
#     }
#     return -1;
# }
#
# borders = []
#
# canvas.onmousedown = ()=>{
#     var pos = getNearestSquare(getMousePos(canvas, mouse));
#     if (pos != null) {
#         index = containsObject(pos, borders)
#         if (index != -1){
#             borders.splice(index, 1)
#             ctx.clearRect(pos.x + 1, pos.y, 19, 19)
#         }
#         else{
#             ctx.fillRect(pos.x+1,pos.y+1,18,18);
#             borders.push(pos)
#         }
#         ctx.fillStyle="#000000";
#     }
# }
# var data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>
# data:image/png;base64,...
# 6006

# %% [markdown]
# #### Φωτογραφία του 4.4 όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
# ![download (2).png](data:image/png;base64,...)
#
#
# ![4.4.png](data:image/png;base64,...)
#
# #### Σχολιασμός
# Γενικότερα, ο αλγόριθμος Α* βρίσκει το μονοπάτι σημαντικά πιο γρήγορα από τον Dijktra οταν η ευριστική είναι αρκετά καλή. Το κύριο πλεονέκτημά του είναι ότι μπορεί να προσδιορίσει πόσο κοντά είναι στο στόχο σε αντίθεση με τον dijktra, ο οποίος κοιτάει πόσο μακριά είναι από το αρχικό κελί. Γιαυτό και αν φτιάξουμε ένα λαβύρινθο ο οποίος να είναι συμμετρικός προς όλες τις κατευθύνσεις, ο dijktra θα επεκτείνει όλα τα μονοπάτια "ταυχόχρονα", ενώ ο Α* θα ακολουθήσει κατευθείαν το μονοπάτι που δείχνει να είναι πιο κοντά στο κελί στόχο.

# %%
g = load_maze('4.4.png')

# %%
# %%time
pf = Pathfinder(g, c = find_c, h = lambda x,y: 0)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())
# Out:
# CPU times: user 50.8 ms, sys: 0 ns, total: 50.8 ms
# Wall time: 59.6 ms

# %%
pf.vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7d14dd55afb84fbba4d7a1dc944e2022">
#   <div class="anim-controls">
#     <input id="_anim_slider7d14dd55afb84fbba4d7a1dc944e2022" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7d14dd55afb84fbba4d7a1dc944e2022.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim7d14dd55afb84fbba4d7a1dc944e2022.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select7d14dd55afb84fbba4d7a1dc944e2022" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7d14dd55afb84fbba4d7a1dc944e2022"
#              >
#       <label for="_anim_radio1_7d14dd55afb84fbba4d7a1dc944e2022">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7d14dd55afb84fbba4d7a1dc944e2022"
#              checked>
#       <label for="_anim_radio2_7d14dd55afb84fbba4d7a1dc944e2022">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7d14dd55afb84fbba4d7a1dc944e2022"
#              >
#       <label for="_anim_radio3_7d14dd55afb84fbba4d7a1dc944e2022">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7d14dd55afb84fbba4d7a1dc944e2022";
#     var slider_id = "_anim_slider7d14dd55afb84fbba4d7a1dc944e2022";
#     var loop_select_id = "_anim_loop_select7d14dd55afb84fbba4d7a1dc944e2022";
#     var frames = new Array(34);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAE/0lEQVR4nO3cQW4iMRRFUSpiR6wgy2WVzjAZAhHY\
# t3zOuKN2VJGu/uQdY4xxAYCYr9kPAIBXCBgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgA\
# SQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAk\
# CRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAk\
# YAAkCRgASQIGQJKAAZAkYAAkCRgASdfZDwB+Hcfx9M+MMZb9f+CdXGAAJAkYAEkCBkCSgAGQJGAA\
# JAkYAEkCBkCSgAGQJGAAJAkYAEkCBkCSgAGQJGAAJAkYAEkCBkCSgAGQJGAAJAkYAEkCBkCSgAGQ\
# JGAAJAkYAEkCBkCSgAGQdJ39AK

# %% [markdown]
# ### 4.5.

# %%
draw(filename='4.5.png')
# Out:
# <canvas width=301 height=301></canvas>
# <br>
#
# <button id = "start" style="background-color: #008000">Start</button>
# <button id = "end" style="background-color: #800000">End</button>
# <button id = "finish">Finish</button>
# <script>
#
# var canvas = document.querySelector('canvas')
# var ctx = canvas.getContext('2d')
#
# for (var x = 0.5; x < 301; x += 20) {
#   ctx.moveTo(x, 0);
#   ctx.lineTo(x, 300);
# }
#
# for (var y = 0.5; y < 301; y += 20) {
#   ctx.moveTo(0, y);
#   ctx.lineTo(300, y);
# }
#
# ctx.strokeStyle = "#000";
# ctx.stroke();
#
# var button = document.getElementById('finish')
# var start_button = document.getElementById('start')
# var end_button = document.getElementById('end')
#
#
# start_button.onclick = ()=>{
#     ctx.fillStyle="#008000";
#   }
#
# end_button.onclick = ()=>{
#     ctx.fillStyle="#800000";
#   }
#
#
# var mouse = {x: 0, y: 0}
# canvas.addEventListener('mousemove', function(e) {
#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop
# })
#
# function getMousePos(canvas, evt) {
#         var rect = canvas.getBoundingClientRect();
#         return {
#           x: evt.x - rect.left,
#           y: evt.y - rect.top
#         };
#       }
#
# function getNearestSquare(position) {
#     var x = position.x;
#     var y = position.y;
#
#     if (x < 0 || y < 0) return null;
#     x = (Math.floor(x / 20) * 20) + 0.5
#     y = (Math.floor(y / 20) * 20) + 0.5
#     return {x: x, y: y};
# }
#
# function containsObject(obj, list) {
#     var i;
#     for (i = 0; i < list.length; i++) {
#         if (list[i].x === obj.x && list[i].y == obj.y) {
#             return i;
#         }
#     }
#     return -1;
# }
#
# borders = []
#
# canvas.onmousedown = ()=>{
#     var pos = getNearestSquare(getMousePos(canvas, mouse));
#     if (pos != null) {
#         index = containsObject(pos, borders)
#         if (index != -1){
#             borders.splice(index, 1)
#             ctx.clearRect(pos.x + 1, pos.y, 19, 19)
#         }
#         else{
#             ctx.fillRect(pos.x+1,pos.y+1,18,18);
#             borders.push(pos)
#         }
#         ctx.fillStyle="#000000";
#     }
# }
# var data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>
# data:image/png;base64,...
# 5430

# %% [markdown]
# #### Φωτογραφία από το 4.5 όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
# ![download (1).png](data:image/png;base64,...)
#
# ![4.5.png](data:image/png;base64,...)
#
# #### Σχολιασμός
# Ο Dijktra είναι ένας greedy uninformed αλγόριθμος, το οποίο σημαίνει ότι συνεχώς θα επεκτείνει το κελί με τη μικρότερη απόσταση από το αρχικό κελί (κατά κάποιο τρόπο μπορούμε να φανταστούμε ότι κάνει BFS). Ο Α* από την άλλη είναι ένας informed αλγόριθμος και αυτό σημαίνει ότι με μία αρκετά καλή ευριστική, μπορεί να οδηγηθεί πολύ γρήγορα στο στόχο χωρίς να παρεκλείνει πολύ από αυτόν (εδώ μπορούμε να τον παρομοιάσουμε με κάποιον DFS αλγόριθμο). Επομένως, για να είμαστε σίγουροι ότι αυτοί οι δύο αλγόριθμοι εκτελούν τον ίδιο αριθμό βημάτων κατά την εκτέλεσή τους, θα πρέπει το δέντρο που χαρακτηρίζει το λαβύρινθο να έχει τη μορφή συνδεδεμένης λίστας (δηλαδή να μην υπάρχουν παρακλάδια).

# %%
g = load_maze('4.5.png')

# %%
pf = Pathfinder(g, c = find_c, h = lambda x, y: 0)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())

# %%
pf.vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9859cfc1fb854fd6bb7cb1ec909b9fda">
#   <div class="anim-controls">
#     <input id="_anim_slider9859cfc1fb854fd6bb7cb1ec909b9fda" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9859cfc1fb854fd6bb7cb1ec909b9fda.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim9859cfc1fb854fd6bb7cb1ec909b9fda.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select9859cfc1fb854fd6bb7cb1ec909b9fda" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9859cfc1fb854fd6bb7cb1ec909b9fda"
#              >
#       <label for="_anim_radio1_9859cfc1fb854fd6bb7cb1ec909b9fda">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9859cfc1fb854fd6bb7cb1ec909b9fda"
#              checked>
#       <label for="_anim_radio2_9859cfc1fb854fd6bb7cb1ec909b9fda">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9859cfc1fb854fd6bb7cb1ec909b9fda"
#              >
#       <label for="_anim_radio3_9859cfc1fb854fd6bb7cb1ec909b9fda">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9859cfc1fb854fd6bb7cb1ec909b9fda";
#     var slider_id = "_anim_slider9859cfc1fb854fd6bb7cb1ec909b9fda";
#     var loop_select_id = "_anim_loop_select9859cfc1fb854fd6bb7cb1ec909b9fda";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAEwklEQVR4nO3cu01DQRRFUQa5ImiAMlwidEEFbukS\
# EEBA4MdvtGGt/MknsbZuMmtm5gYAYm53DwCAzxAwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAA\
# SBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMg\
# ScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAk\
# AQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIE\
# DIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASBIw\
# AJIEDICk0+4BsMNaa/eED83M7g
